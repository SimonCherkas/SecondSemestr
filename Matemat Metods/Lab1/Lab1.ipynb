# %% [markdown]
# # Звіт з візуалізації даних з використанням matplotlib

# %% [markdown]
# ## Імпорт бібліотек

# %%
# %pip install matplotlib
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
# Out:
# Requirement already satisfied: matplotlib in c:\users\anime\appdata\local\programs\python\python312\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anime\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\anime\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anime\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anime\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\anime\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\anime\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\anime\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anime\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anime\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\anime\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Побудова базового графіку

# %%
plt.plot([1, 2, 4, 8])
plt.show()

# %% [markdown]
# ## Випадкові значення та точкова діаграма

# %%
s = 100
rng = np.random.default_rng(seed=101)
x = rng.integers(0, 5, size=s, endpoint=True)
y = rng.integers(0, 100, size=s, endpoint=True)

print(f"""
X має {x.size} елементів, з них унікальні {np.unique(x)}
По Х: Максимум {x.max()}, Мінімум {x.min()}, Середнє значення: {x.mean()}

Y має {y.size} елементів, з них унікальних {np.unique(y).size}
По Y: Максимум {y.max()}, Мінімум {y.min()}, Середнє значення: {y.mean()}
""")
# Out:
# X має 100 елементів, з них унікальні [0 1 2 3 4 5]
# По Х: Максимум 5, Мінімум 0, Середнє значення: 2.4
#
# Y має 100 елементів, з них унікальних 68
# По Y: Максимум 100, Мінімум 2, Середнє значення: 50.45

# %%
plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Випадкові величини х та у')
plt.plot(y.mean().repeat(x.max()+1), "--")
plt.show()

# %% [markdown]
# ## Гістограма значень

# %%
print(np.histogram(y))
plt.hist(y)
plt.title('Гістограма значень y')
plt.xlabel('y')
plt.ylabel('Частота')
plt.show()
# Out:
# (array([14,  9,  8, 11,  9,  6, 13,  8,  7, 15]), array([  2. ,  11.8,  21.6,  31.4,  41.2,  51. ,  60.8,  70.6,  80.4,
#         90.2, 100. ]))

# %% [markdown]
# ## Побудова кількох функцій на одному графіку

# %%
x = np.linspace(0, 5, 100)
ya = (5 - x)/4
yb = (3 - x)**2
yc = (2 - x)
yd = np.full_like(x, 1)

plt.plot(x, ya, label='y = (5 - x)/4')
plt.plot(x, yb, label='y = (3 - x)**2')
plt.plot(x, yc, label='y = 2 - x')
plt.plot(x, yd, label='y = 1')

plt.title('Візуалізація')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ## Висновок
#
# Побудовано базові графіки з використанням бібліотеки matplotlib. Проведено аналіз випадкових величин, їх розподілу, побудовано гістограму та комбіновану візуалізацію декількох функцій.
